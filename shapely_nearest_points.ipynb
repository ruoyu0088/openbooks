# %% [markdown]
# # 用Cython提高Shapely的运算速度

# %%
# %matplotlib inline
# %load_ext cython
import numpy as np
import pylab as pl
import shapely
import shapely.geometry as sg

# %%
angle = np.linspace(0, 2*np.pi, 7)
x, y = np.sin(angle + 0.3) * 1.5, np.cos(angle) * 1.5
line = sg.LineString(zip(x, y))
px, py = np.random.normal(size=(2000, 2)).T
points = sg.MultiPoint(zip(px, py))

# %%
dist = [p.distance(line) for p in points]
fig, ax = pl.subplots(figsize=(8, 8))
ax.set_aspect("equal")
ax.scatter(px, py, c=dist, marker="x")
ax.plot(x, y, "r");

# %%
# %timeit [p.distance(line) for p in points]
# Out:
# 10 loops, best of 3: 42.5 ms per loop

# %%
shapely.geos.lgeos.geos_handle
# Out:
# 121399144

# %%
function_names = [name for name in dir(shapely.geos.lgeos) if name.startswith("GEOS")]
print function_names[:5]
# Out:
# ['GEOSArea', 'GEOSBoundary', 'GEOSBuffer', 'GEOSBufferWithStyle', 'GEOSContains']

# %%
GEOSDistance = shapely.geos.lgeos.GEOSDistance.func
print GEOSDistance.argtypes
print GEOSDistance.restype
# Out:
# [<class 'ctypes.c_void_p'>, <class 'ctypes.c_void_p'>, <class 'ctypes.c_void_p'>, <class 'ctypes.c_void_p'>]
# <class 'ctypes.c_long'>

# %%
tmp = line.impl["distance"]
tmp??

# %% [markdown]
# ```python
# class BinaryRealProperty(Delegating):
#     def __call__(self, this, other):
#         self._validate(this)
#         self._validate(other, stop_prepared=True)
#         d = c_double()
#         retval = self.fn(this._geom, other._geom, byref(d))
#         return d.value
# ```

# %%
tmp.fn

# %%
tmp.fn.func, GEOSDistance
# Out:
# (<_FuncPtr object at 0x09BB6300>, <_FuncPtr object at 0x09BB6300>)

# %%
import ctypes
functions = ["GEOSCoordSeq_create", 
             "GEOSCoordSeq_setX", 
             "GEOSCoordSeq_setY",
             "GEOSGeom_createPoint",
             "GEOSGeom_destroy",
             "GEOSDistance"]

type_map = {
    ctypes.c_void_p: "void *",
    ctypes.c_ulong: "unsigned long",
    ctypes.c_double: "double",
    ctypes.c_long: "long",
    None: "void"
}

for func_name in functions:
    func = getattr(shapely.geos.lgeos, func_name).func
    args = ", ".join(type_map[arg] for arg in func.argtypes)
    res = type_map[func.restype]
    type_name = func_name + "Func"
    print "ctypedef {}(*{})({})".format(res, type_name, args)
    print "cdef {} {}".format(type_name, func_name) 
    print "{} = <{}><unsigned long>cast(lgeos.{}.func, c_void_p).value".format(
        func_name, type_name, func_name)
    print
# Out:
# ctypedef void *(*GEOSCoordSeq_createFunc)(void *, unsigned long, unsigned long)
# cdef GEOSCoordSeq_createFunc GEOSCoordSeq_create
# GEOSCoordSeq_create = <GEOSCoordSeq_createFunc><unsigned long>cast(lgeos.GEOSCoordSeq_create.func, c_void_p).value
#
# ctypedef long(*GEOSCoordSeq_setXFunc)(void *, void *, unsigned long, double)
# cdef GEOSCoordSeq_setXFunc GEOSCoordSeq_setX
# GEOSCoordSeq_setX = <GEOSCoordSeq_setXFunc><unsigned long>cast(lgeos.GEOSCoordSeq_setX.func, c_void_p).value
#
# ctypedef long(*GEOSCoordSeq_setYFunc)(void *, void *, unsigned long, double)
# cdef GEOSCoordSeq_setYFunc GEOSCoordSeq_setY
# GEOSCoordSeq_setY = <GEOSCoordSeq_setYFunc><unsigned long>cast(lgeos.GEOSCoordSeq_setY.func, c_void_p).value
#
# ctypedef void *(*GEOSGeom_createPointFunc)(void *, void *)
# cdef GEOSGeom_createPointFunc GEOSGeom_createPoint
# GEOSGeom_createPoint = <GEOSGeom_createPointFunc><unsigned long>cast(lgeos.GEOSGeom_createPoint.func, c_void_p).value
#
# ctypedef void(*GEOSGeom_destroyFunc)(void *, void *)
# cdef GEOSGeom_destroyFunc GEOSGeom_destroy
# GEOSGeom_destroy = <GEOSGeom_destroyFunc><unsigned long>cast(lgeos.GEOSGeom_destroy.func, c_void_p).value
#
# ctypedef long(*GEOSDistanceFunc)(void *, void *, void *, void *)
# cdef GEOSDistanceFunc GEOSDistance
# GEOSDistance = <GEOSDistanceFunc><unsigned long>cast(lgeos.GEOSDistance.func, c_void_p).value

# %%
# %%cython
# import cython
# import numpy as np
# import shapely
# from shapely.geos import lgeos
# import ctypes
# from ctypes import cast, c_void_p
#
# ctypedef void *(*GEOSCoordSeq_createFunc)(void *, unsigned long, unsigned long)
# cdef GEOSCoordSeq_createFunc GEOSCoordSeq_create
# GEOSCoordSeq_create = <GEOSCoordSeq_createFunc><unsigned long>cast(lgeos.GEOSCoordSeq_create.func, c_void_p).value
#
# ctypedef long(*GEOSCoordSeq_setXFunc)(void *, void *, unsigned long, double)
# cdef GEOSCoordSeq_setXFunc GEOSCoordSeq_setX
# GEOSCoordSeq_setX = <GEOSCoordSeq_setXFunc><unsigned long>cast(lgeos.GEOSCoordSeq_setX.func, c_void_p).value
#
# ctypedef long(*GEOSCoordSeq_setYFunc)(void *, void *, unsigned long, double)
# cdef GEOSCoordSeq_setYFunc GEOSCoordSeq_setY
# GEOSCoordSeq_setY = <GEOSCoordSeq_setYFunc><unsigned long>cast(lgeos.GEOSCoordSeq_setY.func, c_void_p).value
#
# ctypedef void *(*GEOSGeom_createPointFunc)(void *, void *)
# cdef GEOSGeom_createPointFunc GEOSGeom_createPoint
# GEOSGeom_createPoint = <GEOSGeom_createPointFunc><unsigned long>cast(lgeos.GEOSGeom_createPoint.func, c_void_p).value
#
# ctypedef void(*GEOSGeom_destroyFunc)(void *, void *)
# cdef GEOSGeom_destroyFunc GEOSGeom_destroy
# GEOSGeom_destroy = <GEOSGeom_destroyFunc><unsigned long>cast(lgeos.GEOSGeom_destroy.func, c_void_p).value
#
# ctypedef long(*GEOSDistanceFunc)(void *, void *, void *, void *)
# cdef GEOSDistanceFunc GEOSDistance
# GEOSDistance = <GEOSDistanceFunc><unsigned long>cast(lgeos.GEOSDistance.func, c_void_p).value
#
# @cython.wraparound(False)
# @cython.boundscheck(False)
# def distance(geo_obj, double[:] x, double[:] y):
#     cdef int i
#     cdef void * geos_h = <void *><unsigned long>lgeos.geos_handle
#     cdef void * obj_h = <void *><unsigned long>geo_obj._geom
#     cdef void * cs
#     cdef void * point
#     cdef double dist
#     cdef double[::1] result
#     result = np.zeros(x.shape[0])
#     cs = GEOSCoordSeq_create(geos_h, 1, 2)
#     point = GEOSGeom_createPoint(geos_h, cs)
#
#     for i in range(x.shape[0]):
#         GEOSCoordSeq_setX(geos_h, cs, 0, x[i])
#         GEOSCoordSeq_setY(geos_h, cs, 0, y[i])
#         GEOSDistance(geos_h, point, obj_h, &dist)
#         result[i] = dist
#
#     GEOSGeom_destroy(geos_h, point)
#     return result.base

# %%
# %timeit distance(line, px, py)
# Out:
# 100 loops, best of 3: 6.96 ms per loop

# %%
dist2 = distance(line, px, py)
np.all(dist == dist2)
# Out:
# True

# %%
function_names
# Out:
# ['GEOSArea',
#  'GEOSBoundary',
#  'GEOSBuffer',
#  'GEOSBufferWithStyle',
#  'GEOSContains',
#  'GEOSConvexHull',
#  'GEOSCoordSeq_clone',
#  'GEOSCoordSeq_create',
#  'GEOSCoordSeq_destroy',
#  'GEOSCoordSeq_getDimensions',
#  'GEOSCoordSeq_getSize',
#  'GEOSCoordSeq_getX',
#  'GEOSCoordSeq_getY',
#  'GEOSCoordSeq_getZ',
#  'GEOSCoordSeq_setOrdinate',
#  'GEOSCoordSeq_setX',
#  'GEOSCoordSeq_setY',
#  'GEOSCoordSeq_setZ',
#  'GEOSCrosses',
#  'GEOSDelaunayTriangulation',
#  'GEOSDifference',
#  'GEOSDisjoint',
#  'GEOSDistance',
#  'GEOSEnvelope',
#  'GEOSEquals',
#  'GEOSEqualsExact',
#  'GEOSFree',
#  'GEOSGeomFromWKB_buf',
#  'GEOSGeomFromWKT',
#  'GEOSGeomToWKB_buf',
#  'GEOSGeomToWKT',
#  'GEOSGeomType',
#  'GEOSGeomTypeId',
#  'GEOSGeom_clone',
#  'GEOSGeom_createCollection',
#  'GEOSGeom_createLineString',
#  'GEOSGeom_createLinearRing',
#  'GEOSGeom_createPoint',
#  'GEOSGeom_createPolygon',
#  'GEOSGeom_destroy',
#  'GEOSGeom_getCoordSeq',
#  'GEOSGeom_getDimensions',
#  'GEOSGetCentroid',
#  'GEOSGetExteriorRing',
#  'GEOSGetGeometryN',
#  'GEOSGetInteriorRingN',
#  'GEOSGetNumCoordinates',
#  'GEOSGetNumGeometries',
#  'GEOSGetNumInteriorRings',
#  'GEOSGetSRID',
#  'GEOSHasZ',
#  'GEOSInterpolate',
#  'GEOSInterpolateNormalized',
#  'GEOSIntersection',
#  'GEOSIntersects',
#  'GEOSLength',
#  'GEOSLineMerge',
#  'GEOSNearestPoints',
#  'GEOSOverlaps',
#  'GEOSPointOnSurface',
#  'GEOSPolygonize',
#  'GEOSPolygonize_full',
#  'GEOSPrepare',
#  'GEOSPreparedContains',
#  'GEOSPreparedContainsProperly',
#  'GEOSPreparedCovers',
#  'GEOSPreparedGeom_destroy',
#  'GEOSPreparedIntersects',
#  'GEOSProject',
#  'GEOSProjectNormalized',
#  'GEOSQueryCallback',
#  'GEOSRelate',
#  'GEOSRelatePattern',
#  'GEOSSTRtree_create',
#  'GEOSSTRtree_destroy',
#  'GEOSSTRtree_insert',
#  'GEOSSTRtree_query',
#  'GEOSSTRtree_remove',
#  'GEOSSetSRID',
#  'GEOSSimplify',
#  'GEOSSingleSidedBuffer',
#  'GEOSSymDifference',
#  'GEOSTopologyPreserveSimplify',
#  'GEOSTouches',
#  'GEOSUnaryUnion',
#  'GEOSUnion',
#  'GEOSUnionCascaded',
#  'GEOSWKBReader_create',
#  'GEOSWKBReader_destroy',
#  'GEOSWKBReader_read',
#  'GEOSWKBReader_readHEX',
#  'GEOSWKBWriter_create',
#  'GEOSWKBWriter_destroy',
#  'GEOSWKBWriter_getByteOrder',
#  'GEOSWKBWriter_getIncludeSRID',
#  'GEOSWKBWriter_getOutputDimension',
#  'GEOSWKBWriter_setByteOrder',
#  'GEOSWKBWriter_setIncludeSRID',
#  'GEOSWKBWriter_setOutputDimension',
#  'GEOSWKBWriter_write',
#  'GEOSWKBWriter_writeHEX',
#  'GEOSWKTReader_create',
#  'GEOSWKTReader_destroy',
#  'GEOSWKTReader_read',
#  'GEOSWKTWriter_create',
#  'GEOSWKTWriter_destroy',
#  'GEOSWKTWriter_getOutputDimension',
#  'GEOSWKTWriter_setOld3D',
#  'GEOSWKTWriter_setOutputDimension',
#  'GEOSWKTWriter_setRoundingPrecision',
#  'GEOSWKTWriter_setTrim',
#  'GEOSWKTWriter_write',
#  'GEOSWithin',
#  'GEOS_setWKBOutputDims',
#  'GEOSisClosed',
#  'GEOSisEmpty',
#  'GEOSisRing',
#  'GEOSisSimple',
#  'GEOSisValid',
#  'GEOSisValidReason',
#  'GEOSversion']
